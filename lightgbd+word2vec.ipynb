# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#wine_base = pd.read_csv("data/winemag-data_first150k.csv", index_col=0)
wine_base = pd.read_csv("FINAL_stem_tf_parsed_weather.csv", index_col=0)
wine_base.head(5)
# Out:
#          country                                        description  points  \
# vintage
# 1952           8  year ii oak deep oldgold color rich sweet wood...      95
# 1952           8  astonish age rich toffe warm intens concentr d...      96
# 1957           8  great balanc fresh age vener port cours mani w...      95
# 1961           8  old gold color matur colheita great vintag por...      95
# 1963           8  matur port past year rich fig chocol touch alm...      95
#
#          price  province  taster_name  variety  winery     new_1     new_2  \
# vintage
# 1952     499.0       164           13      376   10276  0.100000  0.100000
# 1952     415.0       164           13      376    1703  0.052632  0.003597
# 1957     375.0       164           13      376    8743  0.076923  0.027027
# 1961     320.0       164           13      376    5078  0.100000  0.058824
# 1963     467.0       164           17      376    6238  0.090909  0.005952
#
#           ...         pr_5     pr_6      pr_7      pr_8     pr_9    tas_5  \
# vintage   ...
# 1952      ...     120.1810  54.8968  13.36560  12.36770  71.6485  16.0018
# 1952      ...     120.1810  54.8968  13.36560  12.36770  71.6485  16.0018
# 1957      ...      92.0486  44.2920   6.72316   7.40562  49.3675  15.0959
# 1961      ...      90.5883  43.2681  25.67690   2.98664  43.9189  18.0467
# 1963      ...      38.1876  48.3052   3.52590   4.78859  29.1487  16.1193
#
#            tas_6    tas_7    tas_8    tas_9
# vintage
# 1952     20.1771  21.6355  21.3967  18.5723
# 1952     20.1771  21.6355  21.3967  18.5723
# 1957     18.7823  22.4479  22.4856  20.6839
# 1961     20.0059  21.9887  23.7509  20.2514
# 1963     18.4244  22.1413  20.8027  19.1788
#
# [5 rows x 21 columns]

# %%
from sklearn.model_selection import train_test_split
X = wine_base.drop(['points'], axis=1)
y = wine_base['points'].copy()

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

#vect = CountVectorizer(tokenizer=custom_tokenizer, min_df=5)
vect = CountVectorizer(min_df=5)
vect.fit(X_train['description'])
print("vocabulary size: {}".format(len(vect.vocabulary_)))
X_train_vectored = vect.transform(X_train['description'])
# Out:
# vocabulary size: 5897

# %%
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.model_selection import GridSearchCV

lr = LinearRegression()
lr.fit(X_train_vectored, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
from sklearn.metrics import mean_squared_error
y_pred = lr.predict(X_train_vectored)
mse = mean_squared_error(y_train, y_pred)
mse
# Out:
# 3.589151533211965

# %%
X_test_vectored = vect.transform(X_test['description'])
y_test_pred = lr.predict(X_test_vectored)
mse = mean_squared_error(y_test, y_test_pred)
mse
# Out:
# 4.176147181694122

# %%
df = pd.read_csv("stemmed_tf_parsed_weather.csv", index_col=0)

# %%
df.head(5)
# Out:
#          country  points  price  province  taster_name  variety  winery  \
# vintage
# 1952           8      95  499.0       164           13      376   10276
# 1952           8      96  415.0       164           13      376    1703
# 1957           8      95  375.0       164           13      376    8743
# 1961           8      95  320.0       164           13      376    5078
# 1963           8      95  467.0       164           17      376    6238
#
#             new_1     new_2     new_3      pr_5     pr_6      pr_7      pr_8  \
# vintage
# 1952     0.100000  0.100000  0.004785  120.1810  54.8968  13.36560  12.36770
# 1952     0.052632  0.003597  0.001577  120.1810  54.8968  13.36560  12.36770
# 1957     0.076923  0.027027  0.004785   92.0486  44.2920   6.72316   7.40562
# 1961     0.100000  0.058824  0.003185   90.5883  43.2681  25.67690   2.98664
# 1963     0.090909  0.005952  0.005917   38.1876  48.3052   3.52590   4.78859
#
#             pr_9    tas_5    tas_6    tas_7    tas_8    tas_9
# vintage
# 1952     71.6485  16.0018  20.1771  21.6355  21.3967  18.5723
# 1952     71.6485  16.0018  20.1771  21.6355  21.3967  18.5723
# 1957     49.3675  15.0959  18.7823  22.4479  22.4856  20.6839
# 1961     43.9189  18.0467  20.0059  21.9887  23.7509  20.2514
# 1963     29.1487  16.1193  18.4244  22.1413  20.8027  19.1788

# %%
features=['price']
X = df.loc[:,features]

# %%
X.head(2)
# Out:
#          price
# vintage
# 1952     499.0
# 1952     415.0
