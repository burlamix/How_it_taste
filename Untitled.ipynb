# %%
import pandas as pd
reviews = pd.read_csv("data/winemag-data_first150k.csv", index_col=0)
reviews.head(100)
# Out:
#         country                                        description  \
# 0            US  This tremendous 100% varietal wine hails from ...
# 1         Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2            US  Mac Watson honors the memory of a wine once ma...
# 3            US  This spent 20 months in 30% new French oak, an...
# 4        France  This is the top wine from La Bégude, named aft...
# 5         Spain  Deep, dense and pure from the opening bell, th...
# 6         Spain  Slightly gritty black-fruit aromas include a s...
# 7         Spain  Lush cedary black-fruit aromas are luxe and of...
# 8            US  This re-named vineyard was formerly bottled as...
# 9            US  The producer sources from two blocks of the vi...
# 10        Italy  Elegance, complexity and structure come togeth...
# 11           US  From 18-year-old vines, this supple well-balan...
# 12           US  A standout even in this terrific lineup of 201...
# ...

# %%
reviews['province'].value_counts().head(10).plot.bar()

# %%
(reviews['province'].value_counts().head(10) / len(reviews)).plot.bar()

# %%
reviews['points'].value_counts().sort_index().plot.area()

# %%
reviews[reviews['price'] < 200]['price'].plot.hist()

# %%
#some how check the if the people that rated very expensive wine bottle also review very cheap wine bottle,
#and some how think to normalize their rated
# Out:
#   File "<ipython-input-8-a969651ba167>", line 1
#     some how check the if the people that rated very expensive wine bottle also review very cheap wine bottle,
#            ^
# SyntaxError: invalid syntax

# %%
reviews[reviews['price'] < 80].plot.hexbin(x='price', y='points', gridsize=25)

# %%
reviews.plot.bar(stacked=True)

# %%
#grammar error by the price of wine?

# %%
import seaborn as sns

# %%
sns.kdeplot(reviewslimit.price)

# %%
sns.jointplot(x='price', y='points', data=reviews[reviews['price'] < 100 ], kind='hex', 
              gridsize=20)

# %%
reviewssss = reviews.copy()

# %%
f = (    reviewssss.loc[:, ['price', 'points','country']]).corr()

sns.heatmap(f, annot=True)

# %%
sns.lmplot(x='price', y='points', markers=['o', 'x', '*'], hue='country',
           data=reviews.loc[(reviews['country'].isin([ 'US', 'France','Italy']))& (reviews['price'] < 1000)],
           fit_reg=True
          )

# %%
reviews['province'].value_counts().head(10)
# Out:
# California          44508
# Washington           9750
# Tuscany              7281
# Bordeaux             6111
# Northern Spain       4892
# Mendoza Province     4742
# Oregon               4589
# Burgundy             4308
# Piedmont             4093
# Veneto               3962
# Name: province, dtype: int64
